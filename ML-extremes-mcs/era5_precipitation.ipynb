# %%
import xarray as xr
from datetime import timedelta
import pandas as pd
import numpy as np
import glob
import era5_precipitation

# %%
era5_precipitation.era5_precip_hourly(
    "/glade/collections/rda/data/ds633.4/e5p.oper.fc.sfc.accumu/*/e5p.oper.fc.sfc.accumu.128_142_lsp.ll025sc.*.nc",
    'LSP',
    '/glade/scratch/molina/cesm_mcs/')
# Out:
# List assembled
# e5p.oper.fc.sfc.accumu.128_142_lsp.ll025sc.1954070106_1954071606.nc completed!
# e5p.oper.fc.sfc.accumu.128_142_lsp.ll025sc.1954071606_1954080106.nc completed!
# e5p.oper.fc.sfc.accumu.128_142_lsp.ll025sc.1971121606_1972010106.nc completed!
# e5p.oper.fc.sfc.accumu.128_142_lsp.ll025sc.1971120106_1971121606.nc completed!
# e5p.oper.fc.sfc.accumu.128_142_lsp.ll025sc.1959021606_1959030106.nc completed!
# e5p.oper.fc.sfc.accumu.128_142_lsp.ll025sc.1959020106_1959021606.nc completed!
# e5p.oper.fc.sfc.accumu.128_142_lsp.ll025sc.1952051606_1952060106.nc completed!
# e5p.oper.fc.sfc.accumu.128_142_lsp.ll025sc.1952050106_1952051606.nc completed!
# e5p.oper.fc.sfc.accumu.128_142_lsp.ll025sc.1963111606_1963120106.nc completed!
# e5p.oper.fc.sfc.accumu.128_142_lsp.ll025sc.1963110106_1963111606.nc completed!
# e5p.oper.fc.sfc.accumu.128_142_lsp.ll025sc.1978030106_1978031606.nc completed!
# e5p.oper.fc.sfc.accumu.128_142_lsp.ll025sc.1978031606_1978040106.nc completed!
# ...

# %%
era5_precipitation.era5_precip_hourly(
    "/glade/collections/rda/data/ds633.4/e5p.oper.fc.sfc.accumu/*/e5p.oper.fc.sfc.accumu.128_143_cp.ll025sc.*.nc",
    'CP',
    '/glade/scratch/molina/cesm_mcs/')
