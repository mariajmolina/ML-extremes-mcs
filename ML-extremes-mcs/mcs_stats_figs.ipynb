# %%
import running_mcs_stats

# %%
running_mcs_stats.main()
# Out:
# starting ID generation...
# ID generation complete.
# starting ID generation...
# ID generation complete.
# starting ID generation...
# ID generation complete.
# starting ID generation...
# ID generation complete.
# starting ID generation...
# ID generation complete.
# starting ID generation...
# ID generation complete.
# starting ID generation...
# ID generation complete.
# starting ID generation...
# ID generation complete.
# starting ID generation...
# ID generation complete.
# starting ID generation...
# ID generation complete.
# starting ID generation...
# ID generation complete.
# starting ID generation...
# ID generation complete.
# Percent of month with MCS: [58.29787234 75.         76.99115044 64.85355649 69.16666667 74.16666667
#  66.25       70.83333333 77.5        80.         68.75       85.41666667]
# starting ID generation...
# ID generation complete.
# starting ID generation...
# ID generation complete.
# starting ID generation...
# ID generation complete.
# ...
